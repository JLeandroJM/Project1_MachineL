# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy import stats

# %%
train =  pd.read_csv("train_final.csv")
test= pd.read_csv("test_final.csv")

print(train.columns)
print(test.columns)
# Out:
# Index(['TIPO_PROD_PROY', 'TIPO_ACT_OBRA_ACCINV', 'META', 'CANT_META_ANUAL',
#        'CANT_META_SEM', 'AVAN_FISICO_ANUAL', 'AVAN_FISICO_SEM', 'SEC_FUNC',
#        'CATEGORIA_GASTO', 'MTO_PIA'],
#       dtype='object')
# Index(['TIPO_PROD_PROY', 'TIPO_ACT_OBRA_ACCINV', 'META', 'CANT_META_ANUAL',
#        'CANT_META_SEM', 'AVAN_FISICO_ANUAL', 'AVAN_FISICO_SEM', 'SEC_FUNC',
#        'CATEGORIA_GASTO'],
#       dtype='object')

# %%
tipos_unicos = train['TIPO_PROD_PROY'].unique()
mapeo = {tipo: indice + 1 for indice, tipo in enumerate(tipos_unicos)}
train['TIPO_PROD_PROY_NUM'] = train['TIPO_PROD_PROY'].map(mapeo)
train
print(train['TIPO_PROD_PROY_NUM'].unique())
print(tipos_unicos)
# Out:
# [1 2]
# ['3.PRODUCTO' '2.PROYECTO']

# %%
tipos_unicos = train['TIPO_ACT_OBRA_ACCINV'].unique()
mapeo = {tipo: indice + 1 for indice, tipo in enumerate(tipos_unicos)}
train['TIPO_ACT_OBRA_ACCINV_NUM'] = train['TIPO_ACT_OBRA_ACCINV'].map(mapeo)
train
print(train['TIPO_ACT_OBRA_ACCINV_NUM'].unique())
print(tipos_unicos)
# Out:
# [1 2]
# ['5.ACTIVIDAD' '6.ACCION DE INVERSION']

# %%
tipos_unicos = train['CATEGORIA_GASTO'].unique()
mapeo = {tipo: indice + 1 for indice, tipo in enumerate(tipos_unicos)}
train['CATEGORIA_GASTO_NUM'] = train['CATEGORIA_GASTO'].map(mapeo)
train
print(train['CATEGORIA_GASTO_NUM'].unique())
print(tipos_unicos)
# Out:
# [1 2]
# ['5.GASTOS CORRIENTES' '6.GASTOS DE CAPITAL']

# %%
train
# Out:
#      TIPO_PROD_PROY TIPO_ACT_OBRA_ACCINV  META  CANT_META_ANUAL  \
# 0        3.PRODUCTO          5.ACTIVIDAD     6                0
# 1        3.PRODUCTO          5.ACTIVIDAD    20                0
# 2        3.PRODUCTO          5.ACTIVIDAD     4                0
# 3        3.PRODUCTO          5.ACTIVIDAD     1                0
# 4        3.PRODUCTO          5.ACTIVIDAD     7                0
# ...             ...                  ...   ...              ...
# 1459     3.PRODUCTO          5.ACTIVIDAD    21                0
# 1460     3.PRODUCTO          5.ACTIVIDAD    17                0
# 1461     3.PRODUCTO          5.ACTIVIDAD     3                0
# 1462     3.PRODUCTO          5.ACTIVIDAD    19                0
# 1463     3.PRODUCTO          5.ACTIVIDAD     9                0
#
#       CANT_META_SEM  AVAN_FISICO_ANUAL  AVAN_FISICO_SEM  SEC_FUNC  \
# 0                 6                  0                6         9
# 1                 6                  0                6        23
# 2                16                  0               16        41
# 3                 6                  0                6         4
# 4                 6                  0                6        10
# ...             ...                ...              ...       ...
# 1459              0                  0                0        58
# 1460              0                  0                0        54
# 1461              0                  0                0        40
# 1462              0                  0                0        56
# 1463              0                  0                0        46
#
#           CATEGORIA_GASTO  MTO_PIA
# 0     5.GASTOS CORRIENTES        0
# 1     5.GASTOS CORRIENTES      805
# 2     5.GASTOS CORRIENTES        0
# 3     5.GASTOS CORRIENTES        0
# 4     5.GASTOS CORRIENTES     8816
# ...                   ...      ...
# 1459  5.GASTOS CORRIENTES    12779
# 1460  5.GASTOS CORRIENTES      180
# 1461  5.GASTOS CORRIENTES    31447
# 1462  5.GASTOS CORRIENTES     2250
# 1463  5.GASTOS CORRIENTES     5569
#
# [1464 rows x 10 columns]

# %%
columnas_seleccionadas = ['TIPO_PROD_PROY_NUM', 'TIPO_ACT_OBRA_ACCINV_NUM', 'META','CANT_META_ANUAL','CANT_META_SEM','AVAN_FISICO_ANUAL',
                          'AVAN_FISICO_SEM','SEC_FUNC','CATEGORIA_GASTO_NUM','MTO_PIA']
                          

# Crear un nuevo DataFrame con las columnas seleccionadas
trainf = train[columnas_seleccionadas].copy()
trainf
# Out:
#       TIPO_PROD_PROY_NUM  TIPO_ACT_OBRA_ACCINV_NUM  META  CANT_META_ANUAL  \
# 0                      1                         1     6                0
# 1                      1                         1    20                0
# 2                      1                         1     4                0
# 3                      1                         1     1                0
# 4                      1                         1     7                0
# ...                  ...                       ...   ...              ...
# 1459                   1                         1    21                0
# 1460                   1                         1    17                0
# 1461                   1                         1     3                0
# 1462                   1                         1    19                0
# 1463                   1                         1     9                0
#
#       CANT_META_SEM  AVAN_FISICO_ANUAL  AVAN_FISICO_SEM  SEC_FUNC  \
# 0                 6                  0                6         9
# 1                 6                  0                6        23
# 2                16                  0               16        41
# 3                 6                  0                6         4
# 4                 6                  0                6        10
# ...             ...                ...              ...       ...
# 1459              0                  0                0        58
# 1460              0                  0                0        54
# 1461              0                  0                0        40
# 1462              0                  0                0        56
# 1463              0                  0                0        46
#
#       CATEGORIA_GASTO_NUM  MTO_PIA
# 0                       1        0
# 1                       1      805
# 2                       1        0
# 3                       1        0
# 4                       1     8816
# ...                   ...      ...
# 1459                    1    12779
# 1460                    1      180
# 1461                    1    31447
# 1462                    1     2250
# 1463                    1     5569
#
# [1464 rows x 10 columns]

# %%
trainf['META'].describe()
# Out:
# count    1464.000000
# mean       12.462432
# std         7.395105
# min         1.000000
# 25%         6.000000
# 50%        12.000000
# 75%        18.000000
# max        27.000000
# Name: META, dtype: float64

# %%
sns.histplot(
    trainf["MTO_PIA"], kde=True,
    stat="density", kde_kws=dict(cut=3),
    alpha=.4, edgecolor=(1, 1, 1, .4),
)
# Out:
# <Axes: xlabel='MTO_PIA', ylabel='Density'>

# %%
for columna in trainf.columns:
    
    data = pd.concat([trainf['MTO_PIA'], trainf[columna]], axis=1)
    data.plot.scatter(x=columna, y='MTO_PIA', ylim=(0,800000));

# %%
corrmat = trainf.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
k = 8
cols = corrmat.nlargest(k, 'MTO_PIA')['MTO_PIA'].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
var = 'META'
data = pd.concat([trainf['MTO_PIA'], trainf[var]], axis=1)
data.plot.scatter(x=var, y='MTO_PIA', ylim=(0,800000));

# %%
sns.distplot(trainf['MTO_PIA'], fit=norm);
fig = plt.figure()
res = stats.probplot(trainf['MTO_PIA'], plot=plt)
# Out:
# /var/folders/fx/n685hk8x7534hjymvry9354c0000gn/T/ipykernel_5667/2071073745.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(trainf['MTO_PIA'], fit=norm);
